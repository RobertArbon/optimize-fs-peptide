# %%
import GPy 
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
k1 = GPy.kern.ExpQuad(input_dim=1, active_dims=[0]) # works on the first column of X, index=0
k2 = GPy.kern.ExpQuad(input_dim=1, lengthscale=4, active_dims=[1]) # works on the second column of X, index=1

k3 = GPy.kern.ExpQuad(input_dim=1, lengthscale=2, active_dims=[0]) # works on the first column of X, index=0
k4 = GPy.kern.ExpQuad(input_dim=1, lengthscale=0.5, active_dims=[1]) # works on the second column of X, index=1

k = k1 * k2 + k3 + k4
k.plot(x=np.array([[1,1]]) , xlim=(-5,5), ylim=(-5,5))
# Out:
#  /Users/robertarbon/OneDrive - University of Bristol/Research/optimize_fs_peptide/opt_fs_pep/lib/python3.7/site-packages/GPy/plotting/matplot_dep/plot_definitions.py:184: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
# {'covariance': [<matplotlib.contour.QuadContourSet at 0x1235a0940>]}

# %%
k
# Out:
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  sum.                     </b></th><th><b>value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  mul.ExpQuad.variance     </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mul.ExpQuad.lengthscale  </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mul.ExpQuad_1.variance   </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mul.ExpQuad_1.lengthscale</td><td class=tg-right>  4.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  ExpQuad.variance         </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  ExpQuad.lengthscale      </td><td class=tg-right>  2.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  ExpQuad_1.variance       </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  ExpQuad_1.lengthscale    </td><td class=tg-right>  0.5</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
np.array([[1.0,1.0]])
# Out:
# array([[1., 1.]])

# %%
x = np.linspace(-3, 3, 5).reshape(-1, 1)
x = np.concatenate([x, x], axis=1)
x
# Out:
# array([[-3. , -3. ],
#        [-1.5, -1.5],
#        [ 0. ,  0. ],
#        [ 1.5,  1.5],
#        [ 3. ,  3. ]])

# %%
plt.imshow(k.K(x))

# %%
xx, yy = np.mgrid[-3:3:20j, -3:3:20j]
X = np.vstack((xx.flatten(), yy.flatten())).T

# %%
X[:10, ]
# Out:
# array([[-3.        , -3.        ],
#        [-3.        , -2.68421053],
#        [-3.        , -2.36842105],
#        [-3.        , -2.05263158],
#        [-3.        , -1.73684211],
#        [-3.        , -1.42105263],
#        [-3.        , -1.10526316],
#        [-3.        , -0.78947368],
#        [-3.        , -0.47368421],
#        [-3.        , -0.15789474]])

# %%
k1 = GPy.kern.RBF(input_dim=1, lengthscale=1, variance=2,  active_dims=[0]) # works on the first column of X, index=0
k2 = GPy.kern.RBF(input_dim=1, lengthscale=2, variance=2, active_dims=[1]) # works on the second column of X, index=1
k_mult = k1*k2
plt.imshow(k_mult.K(X))

# %%
k1 = GPy.kern.RBF(input_dim=1, lengthscale=1, variance=1,  active_dims=[0]) # works on the first column of X, index=0
k2 = GPy.kern.RBF(input_dim=1, lengthscale=2, variance=4, active_dims=[1]) # works on the second column of X, index=1
k_mult_1 = k1*k2
k1 = GPy.kern.RBF(input_dim=1, lengthscale=1, variance=2,  active_dims=[0]) # works on the first column of X, index=0
k2 = GPy.kern.RBF(input_dim=1, lengthscale=2, variance=2, active_dims=[1]) # works on the second column of X, index=1
k_mult_2 = k1*k2

(k_mult_1.K(X) - k_mult_2.K(X)).sum()
# Out:
# 0.0

# %%
GPy.kern.RBF?

# %%
k1 = GPy.kern.RBF(input_dim=1, lengthscale=2,  active_dims=[0]) # works on the first column of X, index=0
k2 = GPy.kern.RBF(input_dim=1, lengthscale=3, active_dims=[1]) # works on the second column of X, index=1
k_mult = k1*k2

# %%
z_mult = np.random.multivariate_normal(np.zeros(X.shape[0]), 2*k_mult.K(X))
z_add = np.random.multivariate_normal(np.zeros(X.shape[0]), 2*k_add.K(X))

# %%
plt.imshow(k_mult.K(X))

# %%
plt.imshow(k_add.K(X))

# %% [markdown]
# Multiplicative kernel with additive data

# %%
k_mult_add = k1*k2
m_mult_add = GPy.models.GPRegression(X, Y=z_add[:, np.newaxis], kernel=k_mult_add)
m_mult_add.optimize_restarts(verbose=False)
plt.imshow(k_mult_add.K(X))

# %% [markdown]
# Multiplicative kernel with multiplicative data

# %%
k_mult_mult = k1*k2

m_mult_mult = GPy.models.GPRegression(X, Y=z_mult[:, np.newaxis], kernel=k_mult_mult)
m_mult_mult.optimize_restarts(verbose=False)
plt.imshow(k_mult_mult.K(X))

# %%
k_mult_mult_add = k1*k2 + k1 + k2

m_mult_mult_add = GPy.models.GPRegression(X, Y=z_add[:, np.newaxis], kernel=k_mult_mult_add)
m_mult_mult_add.optimize_restarts(verbose=False)
plt.imshow(k_mult_mult_add.K(X))

# %%
m_mult_mult_add
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -3050.486958478046<br>
# <b>Number of Parameters</b>: 9<br>
# <b>Number of Optimization Parameters</b>: 9<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.           </b></th><th><b>                 value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.mul.rbf.variance     </td><td class=tg-right> 2.940332134049562e-06</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.mul.rbf.lengthscale  </td><td class=tg-right>    7.4153337981520755</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.mul.rbf_1.variance   </td><td class=tg-right>4.3953362483871144e-08</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.mul.rbf_1.lengthscale</td><td class=tg-right>    12.865852135214125</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf.variance         </td><td class=tg-right>    0.6621991031125802</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf.lengthscale      </td><td class=tg-right>    0.4571928114744538</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf_1.variance       </td><td class=tg-right>     0.815934711827806</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf_1.lengthscale    </td><td class=tg-right>    2.6337156936026074</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance  </td><td class=tg-right>3.9898206917017165e-27</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %% [markdown]
# Additive kernel with additive data

# %%
k_add_add = k1 + k2

m_add_add = GPy.models.GPRegression(X, Y=z_add[:, np.newaxis], kernel=k_add_add)
m_add_add.optimize_restarts(verbose=False)
plt.imshow(k_add_add.K(X))

# %% [markdown]
# Additive kernel with multiplicative data

# %%
k_add_mult = k1 + k2

m_add_mult = GPy.models.GPRegression(X, Y=z_mult[:, np.newaxis], kernel=k_add_mult)
m_add_mult.optimize_restarts(verbose=False)
plt.imshow(k_add_mult.K(X))

# %%
def rmsd(m, Xnew=X):
    y_pred, _ = m.predict(Xnew)
    y_obs = m.Y
    return np.sqrt(np.sum((y_pred-y_obs)**2))

# %%
print(rmsd(m_mult_mult)*100)
print(rmsd(m_mult_add)*100)
print(rmsd(m_add_mult)*100)
print(rmsd(m_add_add)*100)
print(rmsd(m_mult_mult_add)*100)
# Out:
# 0.02202391483202561
# 0.023304468311421363
# 672.9723383273688
# 0.005942170518747472
# 0.0055614664648393495

# %%
m_mult_mult
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -2645.30610353495<br>
# <b>Number of Parameters</b>: 5<br>
# <b>Number of Optimization Parameters</b>: 5<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>                value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  mul.rbf.variance       </td><td class=tg-right>   1.6003202312970588</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mul.rbf.lengthscale    </td><td class=tg-right>   1.0174203905089605</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mul.rbf_1.variance     </td><td class=tg-right>   0.9016939533131565</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mul.rbf_1.lengthscale  </td><td class=tg-right>    2.936444064864193</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>3.678441202400049e-17</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
m_mult_add
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -2671.9860324499427<br>
# <b>Number of Parameters</b>: 5<br>
# <b>Number of Optimization Parameters</b>: 5<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>                value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  mul.rbf.variance       </td><td class=tg-right>   0.7964714115493153</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mul.rbf.lengthscale    </td><td class=tg-right>   1.0400335685035502</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mul.rbf_1.variance     </td><td class=tg-right>   2.1359704204291994</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mul.rbf_1.lengthscale  </td><td class=tg-right>    3.188652428476192</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>3.894133082707886e-18</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>
