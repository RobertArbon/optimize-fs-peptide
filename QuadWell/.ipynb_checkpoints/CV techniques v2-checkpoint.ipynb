# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from os.path import join
import pickle
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.model_selection import RepeatedKFold, ShuffleSplit
from sklearn.pipeline import Pipeline
from pyemma.coordinates.clustering import NDGrid
from pyemma.msm import MaximumLikelihoodMSM
import warnings 
warnings.filterwarnings(action='ignore')

# %%
def bootstrap_ci(x, ci=(0.05,.95), n_boot=1000):
    medians = []
    for i in range(n_boot):
        medians.append(np.median(np.random.choice(x,size=x.shape[0], replace=True)))
    medians = np.sort(np.array(medians))
    return medians[int(ci[0]*n_boot)], medians[int(ci[1]*n_boot)]

# %%
stride=10
lag = 30
lag_in_strides = int(lag/stride)

# %%
paths = ['data/100.0pc/quad_well_{:02d}.npy'.format(x) for x in range(100)]
# paths
X1 = [np.load(x) for x in paths]

len(X1)
X1[0].shape
# Out:
# (84401, 1)

# %%
X1 = [x[::stride,:] for x in X1]

# %%
X2 = [y for x in X1 for y in np.array_split(x,2)]
X4 = [y for x in X1 for y in np.array_split(x,4)]
X8 = [y for x in X1 for y in np.array_split(x,8)]
X16 = [y for x in X1 for y in np.array_split(x,16)]

# %%
data = {'1-Splits': X1, '2-Splits': X2, '4-Splits':  X4, '8-Splits': X8}

# %%
model = Pipeline([('cluster', NDGrid(min=-1.2, max=1.2, n_bins_per_feature=200)),
                   ('msm', MaximumLikelihoodMSM(lag=lag_in_strides,score_method='vampe', score_k=2))])

# %%
cv = ShuffleSplit(test_size=0.5, n_splits=10)

# %%
ms = list(np.logspace(np.log10(10), np.log10(1000), 5).astype(int))
print(ms)
# Out:
# [10, 31, 100, 316, 1000]

# %%
search = GridSearchCV(model, cv=cv, param_grid={'cluster__n_bins_per_feature': ms} )

# %%
results = {}
for k, v in data.items():
    print(k)
    search.fit(v)
    results[k] = pd.DataFrame(search.cv_results_)
# Out:
# 2-Splits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-305-31d8e9eebdf6> in <module>()
#       2 for k, v in data.items():
#       3     print(k)
# ----> 4     search.fit(v)
#       5     results[k] = pd.DataFrame(search.cv_results_)
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     637                                   error_score=self.error_score)
#     638           for parameters, (train, test) in product(candidate_params,
# --> 639                                                    cv.split(X, y, groups)))
#     640
#     641         # if one choose to see train score, "out" will contain train score info
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     486         fit_time = time.time() - start_time
#     487         # _score will return dict if is_multimetric is True
# --> 488         test_scores = _score(estimator, X_test, y_test, scorer, is_multimetric)
#     489         score_time = time.time() - start_time - fit_time
#     490         if return_train_score:
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/sklearn/model_selection/_validation.py in _score(estimator, X_test, y_test, scorer, is_multimetric)
#     521     """
#     522     if is_multimetric:
# --> 523         return _multimetric_score(estimator, X_test, y_test, scorer)
#     524     else:
#     525         if y_test is None:
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/sklearn/model_selection/_validation.py in _multimetric_score(estimator, X_test, y_test, scorers)
#     549     for name, scorer in scorers.items():
#     550         if y_test is None:
# --> 551             score = scorer(estimator, X_test)
#     552         else:
#     553             score = scorer(estimator, X_test, y_test)
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/sklearn/metrics/scorer.py in _passthrough_scorer(estimator, *args, **kwargs)
#     242 def _passthrough_scorer(estimator, *args, **kwargs):
#     243     """Function that wraps estimator.score"""
# --> 244     return estimator.score(*args, **kwargs)
#     245
#     246
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     113
#     114         # lambda, but not partial, allows help() to work with update_wrapper
# --> 115         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     116         # update the docstring of the returned function
#     117         update_wrapper(out, self.fn)
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/sklearn/pipeline.py in score(self, X, y, sample_weight)
#     488         if sample_weight is not None:
#     489             score_params['sample_weight'] = sample_weight
# --> 490         return self.steps[-1][-1].score(Xt, y, **score_params)
#     491
#     492     @property
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pyEMMA-2.4+903.g71164ed0.dirty-py3.5-macosx-10.6-x86_64.egg/pyemma/msm/estimators/maximum_likelihood_msm.py in score(self, dtrajs, score_method, score_k)
#     299         from pyemma.util.metrics import vamp_score
#     300         return vamp_score(K, C00_train, C0t_train, Ctt_train, C00_test, C0t_test, Ctt_test,
# --> 301                           k=self.score_k, score=self.score_method)
#     302
#     303     def _blocksplit_dtrajs(self, dtrajs, sliding):
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pyEMMA-2.4+903.g71164ed0.dirty-py3.5-macosx-10.6-x86_64.egg/pyemma/util/metrics.py in vamp_score(K, C00_train, C0t_train, Ctt_train, C00_test, C0t_test, Ctt_test, k, score)
#     227         return vamp_2_score(K, C00_train, C0t_train, Ctt_train, C00_test, C0t_test, Ctt_test, k=k)
#     228     elif score.lower() == 'vampe':
# --> 229         return vamp_e_score(K, C00_train, C0t_train, Ctt_train, C00_test, C0t_test, Ctt_test, k=k)
#     230     else:
#     231         raise ValueError('Unknown score: ' + str(score))
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pyEMMA-2.4+903.g71164ed0.dirty-py3.5-macosx-10.6-x86_64.egg/pyemma/util/metrics.py in vamp_e_score(K, C00_train, C0t_train, Ctt_train, C00_test, C0t_test, Ctt_test, k)
#     212     """
#     213     # SVD of symmetrized operator in empirical distribution
# --> 214     U, s, V = _svd_sym_koopman(K, C00_train, Ctt_train)
#     215     if k is not None:
#     216         U = U[:, :k]
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pyEMMA-2.4+903.g71164ed0.dirty-py3.5-macosx-10.6-x86_64.egg/pyemma/util/metrics.py in _svd_sym_koopman(K, C00_train, Ctt_train)
#      16     C0t_re = mdot(C00_train, K)
#      17     # symmetrized operator and SVD
# ---> 18     K_sym = mdot(spd_inv_sqrt(C00_train), C0t_re, spd_inv_sqrt(Ctt_train))
#      19     U, S, Vt = np.linalg.svd(K_sym, compute_uv=True, full_matrices=False)
#      20     # projects back to singular functions of K
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pyEMMA-2.4+903.g71164ed0.dirty-py3.5-macosx-10.6-x86_64.egg/pyemma/_ext/variational/solvers/direct.py in spd_inv_sqrt(W, epsilon, method, canonical_signs)
#     157         Winv = 1./_np.sqrt(W[0,0])
#     158     else:
# --> 159         sm, Vm = spd_eig(W, epsilon=epsilon, method=method, canonical_signs=canonical_signs)
#     160         Winv = _np.dot(Vm, _np.diag(1.0 / _np.sqrt(sm))).dot(Vm.T)
#     161
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pyEMMA-2.4+903.g71164ed0.dirty-py3.5-macosx-10.6-x86_64.egg/pyemma/_ext/variational/solvers/direct.py in spd_eig(W, epsilon, method, canonical_signs)
#      53     if method.lower() == 'qr':
#      54         from .eig_qr.eig_qr import eig_qr
# ---> 55         s, V = eig_qr(W)
#      56     # compute the Eigenvalues of C0 using Schur factorization
#      57     elif method.lower() == 'schur':
#
# pyemma/_ext/variational/solvers/eig_qr/eig_qr.pyx in pyemma._ext.variational.solvers.eig_qr.eig_qr.eig_qr (pyemma/_ext/variational/solvers/eig_qr/eig_qr.c:3383)()
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/numpy/core/numeric.py in require(a, dtype, requirements)
#     619
#     620
# --> 621 def require(a, dtype=None, requirements=None):
#     622     """
#     623     Return an ndarray of the provided type that satisfies requirements.
#
# KeyboardInterrupt:

# %%
all_dfs = []
for nsplits, df  in results.items():
    fold_dfs = []
    id_var = list(df.filter(regex='param_', axis=1).columns)[0]
    for fold in ['test', 'train']:
        fold_df = df.filter(regex='split[0-9]_{}|param_'.format(fold), axis=1)
        fold_df = pd.melt(frame=fold_df, id_vars=id_var, var_name='fold', value_name='VAMP-E')
        fold_df['fold'] = fold
        fold_df['n_traj_splits'] = nsplits
        fold_dfs.append(fold_df)
    all_dfs.append(pd.concat(fold_dfs))
df = pd.concat(all_dfs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-306-7841a432ae7a> in <module>()
#      10         fold_dfs.append(fold_df)
#      11     all_dfs.append(pd.concat(fold_dfs))
# ---> 12 df = pd.concat(all_dfs)
#      13
#      14
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/tools/merge.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     843                        keys=keys, levels=levels, names=names,
#     844                        verify_integrity=verify_integrity,
# --> 845                        copy=copy)
#     846     return op.get_result()
#     847
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/tools/merge.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     876
#     877         if len(objs) == 0:
# --> 878             raise ValueError('No objects to concatenate')
#     879
#     880         if keys is None:
#
# ValueError: No objects to concatenate

# %%
df.shape
# Out:
# (400, 4)

# %%
df.sort_values(by='n_traj_splits', inplace=True)

# %%
with sns.plotting_context('talk', font_scale=1):
    sns.set_style('white')
    g = sns.FacetGrid(data=df.loc[df['fold']=='test',:],  col='n_traj_splits', aspect=1.1)
    g.map(sns.boxplot, 'param_cluster__n_bins_per_feature', 'VAMP-E', saturation=1, linewidth=1,
          whis=10, boxprops=dict(alpha=.8))
    g.map(sns.swarmplot, 'param_cluster__n_bins_per_feature', 'VAMP-E', color='k', alpha=0.5)
    g.set(xlabel='m')
    g.set_titles('{col_name}')
    plt.savefig('figures/traj_splits_vs_score.png', transparent=True)

# %%
with sns.plotting_context('talk', font_scale=1):
    sns.set_style('white')
    g = sns.FacetGrid(data=df.loc[df['fold']=='test',:], aspect=1.1)
    g.map(sns.pointplot, 'param_cluster__n_bins_per_feature', 'VAMP-E', 'n_traj_splits',
          estimator=np.median, ci=None, join=False, dodge=True, markers=['O']*4, scale=1,  palette='colorblind')
    g.set(xlabel='m', ylim=(1.918,1.936))
    g.set_titles('{col_name}')
    g.add_legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'fold'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-304-bc2016fffbe4> in <module>()
#       1 with sns.plotting_context('talk', font_scale=1):
#       2     sns.set_style('white')
# ----> 3     g = sns.FacetGrid(data=df.loc[df['fold']=='test',:], aspect=1.1)
#       4     g.map(sns.pointplot, 'param_cluster__n_bins_per_feature', 'VAMP-E', 'n_traj_splits',
#       5           estimator=np.median, ci=None, join=False, dodge=True, markers=['O']*4, scale=1,  palette='colorblind')
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'fold'

# %%
cv.n_splits=50
model.set_params(cluster__n_bins_per_feature=100)
scores = cross_val_score(X=X8,cv=cv, estimator=model)

# %%
n_splits = np.arange(5,51,5)
n_cis = [bootstrap_ci(scores[:n]) for n in n_splits]
n_cis = [y - x for x,y in n_cis]
n_meds = [np.median(scores[:n]) for n in n_splits]

# %%
n_cis
# Out:
# [0.009150190652849055,
#  0.0027461611297123767,
#  0.0025008994635307147,
#  0.0018638385719649264,
#  0.0021320000090192526,
#  0.0019257727496324595,
#  0.001668321906364234,
#  0.0015216360851966204,
#  0.001646537134312176,
#  0.0015526190659129746]

# %%
n_scores = [ x for n in n_splits for x in scores[:n]]


df_scores = pd.DataFrame(data={'n_splits': [ x  for n in n_splits for x in [n]*n], 'VAMP-E': n_scores})
df_scores.shape
# Out:
# (275, 2)

# %%
with sns.plotting_context('talk', font_scale=1):
#     sns.pointplot( data=df_scores, x='n_splits', y='VAMP-E',ci=None, color=cols[0], label='Mean CV')
    sns.pointplot(data=df_scores, x='n_splits', y='VAMP-E', ci=None, 
                  join=False, estimator=np.median, color=cols[0], label='Median CV')
    sns.stripplot(data=df_scores, x='n_splits', y='VAMP-E',color=cols[0], alpha=0.5)
    plt.ylabel('Median VAMP-E')
    plt.xlabel('Shuffle-split iterations')
    plt.savefig('figures/median_vs_nsplits.png', transparent=True)
    plt.ylim((1.918,1.936))

# %%
with sns.plotting_context('talk', font_scale=1):
#     plt.scatter(n_splits, n_cis)
    plt.scatter(n_splits[:-1], 100*(np.array(n_cis[:-1])/np.array(n_cis[1:])-1), color=cols[0])
    plt.hlines(0,0,50, color='k', lw=1.5)
    plt.xlim(0,50)
    plt.ylabel('Change in Median VAMP-E Confidence Interval width (%)')
    plt.xlabel('Shuffle-split iterations')
    plt.savefig('figures/median_CI_vs_nsplits.png', transparent=True)


#     plt.n

# %%
with sns.plotting_context('talk', font_scale=1):
    fig, axes = plt.subplots(3,sharex=True)
    
    ##
    ax = axes[0]
    sns.pointplot(data=df_scores, x='n_splits', y='VAMP-E', ci=None, 
                  join=False, estimator=np.median, color=cols[0], label='Median CV', ax=ax)
    sns.stripplot(data=df_scores, x='n_splits', y='VAMP-E',color=cols[0], alpha=0.5, ax=ax)
    ax.set_ylabel('Median VAMP-E')
    ax.set_xlabel('')
    ax.set_ylim((1.918,1.936))
    
    ##
    ax = axes[1]
    n = n_splits.shape[0]-1
    ax.scatter(np.arange(n), 100*(np.array(n_meds[:-1])/np.array(n_meds[1:])-1), color=cols[0], s=100)
    ax.hlines(0,-1,n+1, color='k', lw=1.5)
    
#     ax.xlabels(n_splits[:-1])
    ax.set_xlim(-1,n+1)
    ax.set_ylabel('$\Delta$(Medinan VAMP-E) (%)')
    
    ax = axes[2]
    ax.scatter(np.arange(n), 100*(np.array(n_cis[:-1])/np.array(n_cis[1:])-1), color=cols[0], s=100)
    ax.hlines(0,-1,n+1, color='k', lw=1.5)
    
#     ax.xlabels(n_splits[:-1])
    ax.set_xlim(-1,n+1)
    ax.set_ylabel('$\Delta(\Delta$ CI) (%)')
    ax.set_xlabel('Shuffle-split iterations')
    
    plt.savefig('figures/CV_scores_vs_n_splits.png', transparent=True)
